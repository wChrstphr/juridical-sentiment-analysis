# %% [markdown]
# #

# %% [markdown]
# # 📊 NOTEBOOK 1: COLETA E PREPARAÇÃO DE DADOS
# **Análise de Sentimento em Decisões Judiciais - TJCE**

# %% [markdown]
# ## 🔧 1. CONFIGURAÇÃO DO AMBIENTE

# %% [markdown]
# ### 1.1 Instalação de Dependências
# **Descrição**: Instalação das bibliotecas Python necessárias.

# %%
# Instalar bibliotecas necessárias
# !pip install -r requirements.txt
# Out:
# Running cells with 'Python 3.13.12' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/joaomarcos.andrade/AppData/Local/Microsoft/WindowsApps/python3.13.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### 1.2 Importação de Bibliotecas

# %%
import pandas as pd
import json
from collections import Counter
import requests
import csv

# %% [markdown]
# ## 📥 2. COLETA DE DADOS VIA API CNJ *DATAJUD*

# %% [markdown]
# ### 2.1 Configuração da API e Parâmetros de Busca
#
#  **Descrição**: Configuração da requisição à API pública do CNJ. O código de assunto 12487 refere-se a "Fornecimento de medicamentos", encontrado no site oficial do CNJ (https://www.cnj.jus.br/sgt/consulta_publica_assuntos.php).
#
#  Para encontrar o código no site do cnj:
#    1. Procure por "Medicamentos"
#    2. Selecione a 4ª opção: `Fornecimento de medicamentos`
#    3. Verifique o código que aparece, `12487 Fornecimento de medicamentos`

# %%
url = "https://api-publica.datajud.cnj.jus.br/api_publica_tjal/_search"
api_key = "APIKey cDZHYzlZa0JadVREZDJCendQbXY6SkJlTzNjLV9TRENyQk1RdnFKZGRQdw=="

payload = json.dumps({
    "size": 10000,
    "query": {"match": {"assuntos.codigo": "12487"}},  # Código: Fornecimento de medicamentos
    "sort": [{"dataAjuizamento": {"order": "desc"}}]
})

headers = {
    'Authorization': api_key,
    'Content-Type': 'application/json'
}

# %% [markdown]
# ### 2.2 Requisição e Validação dos Dados
# **Descrição**: Execução da requisição HTTP POST para a API e validação inicial do volume de dados retornados.

# %%
response = requests.request("POST", url, headers=headers, data=payload)
dados_dict = response.json()
print(f"Total de processos encontrados na API: {dados_dict['hits']['total']['value']}")
print(f"Processos retornados nesta consulta: {len(dados_dict['hits']['hits'])}")
# Out:
# Total de processos encontrados na API: 224
# Processos retornados nesta consulta: 224

# %% [markdown]
# ## 🔄 3. PROCESSAMENTO E ESTRUTURAÇÃO DOS DADOS

# %% [markdown]
# ### 3.1 Extração de Campos Essenciais
# **Descrição**: Extração dos campos essenciais de cada processo (número, grau de jurisdição, data de ajuizamento e movimentos processuais) e criação do DataFrame principal.

# %%
processos = []

for hit in dados_dict['hits']['hits']:
    processo = hit['_source']

    numero_processo = processo['numeroProcesso']
    grau = processo['grau']
    data_ajuizamento = processo['dataAjuizamento']
    movimentos = processo.get('movimentos', [])

    processos.append([
        numero_processo,
        grau,
        data_ajuizamento,
        movimentos
    ])

df = pd.DataFrame(
    processos,
    columns=[
        'numero_processo',
        'grau',
        'data_ajuizamento',
        'movimentos'
    ]
)

print(f"Total de processos no DataFrame: {len(df)}")
df.sample(5)
# Out:
# Total de processos no DataFrame: 224
#           numero_processo grau          data_ajuizamento  \
# 217  07015415920198010001   G2  2021-01-13T12:39:57.000Z
# 50   07003136720248010003   G2            20240904224700
# 146  10003506420238010000   G2  2023-03-14T15:29:01.000Z
# 73   07005432820238010009   G1            20230519114600
# 35   07040358120258010001   JE            20250317072504
#
#                                             movimentos
# 217  [{'complementosTabelados': [{'codigo': 4, 'val...
# 50   [{'codigo': 11383, 'nome': 'Ato ordinatório', ...
# 146  [{'complementosTabelados': [{'codigo': 4, 'val...
# 73   [{'complementosTabelados': [{'codigo': 19, 'va...
# 35   [{'complementosTabelados': [{'codigo': 4, 'val...

# %% [markdown]
# ## 🔍 4. IDENTIFICAÇÃO E ANÁLISE DE DECISÕES

# %% [markdown]
# ### 4.1 Definição de Termos de Decisão
# **Descrição**: Definição dos termos-chave que caracterizam decisões judiciais relevantes para a análise.

# %%
from collections import Counter

termos_decisao = [
    "Procedência",
    "Improcedência",
    "Improcedência do pedido e improcedência do pedido contraposto",
    "Procedência do pedido e procedência do pedido contraposto",
    "Deferido",
    "Indeferido",
]

# %% [markdown]
# ### 4.2 Extração de Decisões dos Movimentos Processuais
# **Descrição**: Busca sistemática nos movimentos processuais por termos de decisão.
#
# **Importante**: Filtra apenas processos de primeira instância (grau G1) para garantir homogeneidade na análise.

# %%
decisoes_por_processo = []
tipos_decisao_contagem = []

for _, row in df.iterrows():
    numero = row['numero_processo']
    movimentos = row['movimentos']
    grau = row['grau']
    data_ajuizamento = row['data_ajuizamento']

    decisoes_encontradas = []

    if movimentos:
        for mov in movimentos:
            nome_mov = mov.get('nome', '')

            # Filtrar apenas decisões de primeira instância (G1)
            if any(termo in nome_mov for termo in termos_decisao) and grau == 'G1':
                decisoes_encontradas.append(nome_mov)
                tipos_decisao_contagem.append(nome_mov)

    if decisoes_encontradas:
        decisoes_por_processo.append({
            'numero_processo': numero,
            'data_ajuizamento': data_ajuizamento,
            'decisoes': decisoes_encontradas
        })

print(f"Processos com decisões: {len(decisoes_por_processo)} de {len(df)}")
print("\nTipos de decisões encontradas:")
for tipo, count in Counter(tipos_decisao_contagem).most_common(10):
    print(f"  {tipo}: {count}")
# Out:
# Processos com decisões: 61 de 224
#
# Tipos de decisões encontradas:
#   Procedência: 32
#   Improcedência: 18
#   Procedência em Parte: 8
#   Procedência do Pedido - Reconhecimento pelo réu: 6

# %% [markdown]
# ### 4.3 Criação de DataFrame de Decisões
# **Descrição**: Criação de um DataFrame específico para decisões, removendo duplicatas por processo (mantém apenas a primeira decisão encontrada).

# %%
decisoes_lista = []

for item in decisoes_por_processo:
    for decisao in item['decisoes']:
        decisoes_lista.append({
            'numero_processo': item['numero_processo'],
            'tipo_decisao': decisao,
        })

df_decisoes = pd.DataFrame(decisoes_lista)
df_decisoes = df_decisoes.drop_duplicates(subset='numero_processo', keep='first')
df_decisoes.head(10)
# Out:
#         numero_processo                                     tipo_decisao
# 0  07150573920258010001                                    Improcedência
# 1  07097544420258010001                                      Procedência
# 2  07225621820248010001                                      Procedência
# 3  07184033220248010001                             Procedência em Parte
# 4  07156466520248010001                                    Improcedência
# 5  07080815020248010001                                      Procedência
# 6  07077835820248010001                             Procedência em Parte
# 7  07063960820248010001                                      Procedência
# 8  07003422020248010003  Procedência do Pedido - Reconhecimento pelo réu
# 9  07003136720248010003                                      Procedência

# %% [markdown]
# ## 📊 5. SEGMENTAÇÃO POR TIPO DE DECISÃO

# %% [markdown]
# ### 5.1 Separação por Categorias de Decisão
# **Descrição**: Segmentação do dataset em categorias de decisão para análise comparativa posterior.

# %%
# Separar decisões por tipo
df_procedencia = df_decisoes[df_decisoes['tipo_decisao'] == 'Procedência'].copy()
df_improcedencia = df_decisoes[df_decisoes['tipo_decisao'] == 'Improcedência'].copy()

df_decisoes_completo = pd.concat([
    df_procedencia,
    df_improcedencia,
])

print(f"\n=== TODOS OS REGISTROS COM DECISÃO ===")
print(f"Total de registros: {len(df_decisoes_completo)}")
print(f"\nDistribuição por tipo:")
print(f"  - Procedência: {len(df_procedencia)}")
print(f"  - Improcedência: {len(df_improcedencia)}")

df_decisoes_completo
# Out:
# === TODOS OS REGISTROS COM DECISÃO ===
# Total de registros: 53
#
# Distribuição por tipo:
#   - Procedência: 30
#   - Improcedência: 18
#   - Procedência (reu): 5
#          numero_processo                                     tipo_decisao
# 1   07097544420258010001                                      Procedência
# 2   07225621820248010001                                      Procedência
# 5   07080815020248010001                                      Procedência
# 7   07063960820248010001                                      Procedência
# 9   07003136720248010003                                      Procedência
# 16  07011047020238010003                                      Procedência
# 17  07005432820238010009                                      Procedência
# 21  08001645320228010002                                      Procedência
# 22  08001636820228010002                                      Procedência
# 23  08001628320228010002                                      Procedência
# 26  07007689720228010004                                      Procedência
# 29  07099415720228010001                                      Procedência
# 32  07000315720228010081                                      Procedência
# 33  08000181220228010002                                      Procedência
# 34  07159004320218010001                                      Procedência
# 37  07137136220218010001                                      Procedência
# 40  07123749720238010001                                      Procedência
# 41  07008239620238010009                                      Procedência
# 43  07043308920238010001                                      Procedência
# 44  07003260320238010003                                      Procedência
# 47  07155857820228010001                                      Procedência
# 48  07155761920228010001                                      Procedência
# 50  07108648320228010001                                      Procedência
# 51  07005601020228010006                                      Procedência
# 53  07076975820228010001                                      Procedência
# 56  07000378020228010011                                      Procedência
# 59  07004747020218010007                                      Procedência
# 60  07000260920218010004                                      Procedência
# 61  00122208820158010070                                      Procedência
# 63  07005539320148010007                                      Procedência
# 0   07150573920258010001                                    Improcedência
# 4   07156466520248010001                                    Improcedência
# 10  07000607620248010004                                    Improcedência
# 11  07000223720248010013                                    Improcedência
# 14  07169243820238010001                                    Improcedência
# 15  07155958820238010001                                    Improcedência
# 18  07031677420238010001                                    Improcedência
# 19  00012332520238010001                                    Improcedência
# 24  07142640820228010001                                    Improcedência
# 25  07134560320228010001                                    Improcedência
# 27  07101710220228010001                                    Improcedência
# 30  07043666820228010001                                    Improcedência
# 36  07147148220218010001                                    Improcedência
# 42  07046581920238010001                                    Improcedência
# 49  07155329720228010001                                    Improcedência
# 52  07080474620228010001                                    Improcedência
# 55  07075469220228010001                                    Improcedência
# 57  07099981220218010001                                    Improcedência
# 8   07003422020248010003  Procedência do Pedido - Reconhecimento pelo réu
# 28  07013125520228010014  Procedência do Pedido - Reconhecimento pelo réu
# 31  07004761820228010003  Procedência do Pedido - Reconhecimento pelo réu
# 38  07008593620178010014  Procedência do Pedido - Reconhecimento pelo réu
# 46  07000133320238010006  Procedência do Pedido - Reconhecimento pelo réu

# %% [markdown]
# ## 🧹 6. LIMPEZA E CONSOLIDAÇÃO DO DATASET

# %% [markdown]
# ### 6.1 Unificação dos DataFrames
# **Descrição**: Integração da coluna de tipo de decisão ao DataFrame principal.

# %%
df['tipo_decisao'] = df_decisoes_completo['tipo_decisao']
display(df.head(4))
# Out:
#         numero_processo grau data_ajuizamento  \
# 0  07063960820248010001   G2   20260130095119
# 1  50011822120268010001   G1   20260120140304
# 2  50009207120268010001   JE   20260116122411
# 3  07040358120258010001   TR   20260107100445
#
#                                           movimentos   tipo_decisao
# 0  [{'codigo': 15502, 'nome': '', 'dataHora': '20...  Improcedência
# 1  [{'complementosTabelados': [{'codigo': 4, 'val...    Procedência
# 2  [{'codigo': 1051, 'nome': 'Decurso de Prazo', ...    Procedência
# 3  [{'codigo': 15498, 'nome': '', 'dataHora': '20...            NaN

# %% [markdown]
# ### 6.2 Remoção de Valores Nulos

# %%
# Removendo registros NaN
df = df.dropna(subset=['tipo_decisao'])
display(df.head(4))
# Out:
#         numero_processo grau data_ajuizamento  \
# 0  07063960820248010001   G2   20260130095119
# 1  50011822120268010001   G1   20260120140304
# 2  50009207120268010001   JE   20260116122411
# 4  50090975820258010001   JE   20251218150317
#
#                                           movimentos   tipo_decisao
# 0  [{'codigo': 15502, 'nome': '', 'dataHora': '20...  Improcedência
# 1  [{'complementosTabelados': [{'codigo': 4, 'val...    Procedência
# 2  [{'codigo': 1051, 'nome': 'Decurso de Prazo', ...    Procedência
# 4  [{'complementosTabelados': [{'codigo': 3, 'val...  Improcedência

# %% [markdown]
# ### 6.3 Remoção de Colunas Intermediárias

# %%
# Removendo colunas intermediárias
df = df.drop(columns=['grau', 'movimentos', 'tipo_decisao'])
display(df.head(4))
# Out:
#         numero_processo data_ajuizamento
# 0  07063960820248010001   20260130095119
# 1  50011822120268010001   20260120140304
# 2  50009207120268010001   20260116122411
# 4  50090975820258010001   20251218150317

# %% [markdown]
# ### 6.4 Reset de Índice

# %%
# Resetando index para manter organização do dataframe
df = df.reset_index(drop=True)
display(df.head(4))
# Out:
#         numero_processo data_ajuizamento
# 0  07063960820248010001   20260130095119
# 1  50011822120268010001   20260120140304
# 2  50009207120268010001   20260116122411
# 3  50090975820258010001   20251218150317

# %% [markdown]
# ## 📅 7. EXTRAÇÃO DE FEATURES TEMPORAIS

# %% [markdown]
# ### 7.1 Extração de Dia da Semana e Ano
# **Descrição**: Criação de features temporais (dia da semana e ano) para análise de padrões temporais nas decisões judiciais.

# %%
import pandas as pd

# Converter data_ajuizamento para datetime
df['data_ajuizamento_dt'] = pd.to_datetime(
    df['data_ajuizamento'],
    format='%Y%m%d%H%M%S'
)

dias_semana = {0: "Segunda", 1: "Terça", 2: "Quarta", 3: "Quinta", 4: "Sexta"}

# Extrair dia da semana (segunda = 0 | terça = 1 | ... | sexta = 4)
df['dia_semana'] = df['data_ajuizamento_dt'].dt.weekday.map(dias_semana)
df['ano'] = df['data_ajuizamento_dt'].dt.year

# Excluir coluna intermediária
df = df.drop(columns=['data_ajuizamento', 'data_ajuizamento_dt'])

df
# Out:
#          numero_processo dia_semana   ano
# 0   07063960820248010001      Sexta  2026
# 1   50011822120268010001      Terça  2026
# 2   50009207120268010001      Sexta  2026
# 3   50090975820258010001     Quinta  2025
# 4   50089157220258010001     Quarta  2025
# 5   50000852320258010000     Quarta  2025
# 6   50000730920258010000      Terça  2025
# 7   07012417420258010070      Terça  2025
# 8   50000705420258010000      Sexta  2025
# 9   50068050320258010001     Quinta  2025
# 10  07137898120248010001     Quinta  2025
# 11  50000148420258019000     Quinta  2025
# 12  50000087720258019000     Quinta  2025
# 13  07150573920258010001    Segunda  2025
# 14  07001053120258010009      Sexta  2025
# 15  10018673620258010000     Quarta  2025
# 16  07135478820258010001      Sexta  2025
# 17  10017097820258010000      Sexta  2025
# 18  07184033220248010001     Quarta  2025
# 19  07156466520248010001     Quarta  2025
# 20  00006964520258010070      Terça  2025
# 21  07225621820248010001      Terça  2025
# 22  07036547320258010001     Quinta  2025
# 23  07097544420258010001    Segunda  2025
# 24  07063724320258010001      Terça  2025
# 25  07026473320258010070      Terça  2025
# 26  07023961520258010070    Segunda  2025
# 27  07004761820228010003     Quinta  2025
# 28  07019094520258010070    Segunda  2025
# 29  07077835820248010001    Segunda  2025
# 30  07036547320258010001      Terça  2025
# 31  07012417420258010070      Terça  2025
# 32  00007025220258010070     Quinta  2025
# 33  07004709620258010070     Quarta  2025
# 34  07036826220248010070     Quinta  2025
# 35  07155958820238010001      Terça  2024
# 36  07225621820248010001     Quinta  2024
# 37  07007513620238010001     Quinta  2024
# 38  07025523720248010070     Quinta  2024
# 39  07204082720248010001      Terça  2024
# 40  07184033220248010001     Quarta  2024
# 41  01020749420248010000     Quarta  2024
# 42  07003136720248010003     Quarta  2024
# 43  07156466520248010001      Terça  2024
# 44  07182754620238010001    Segunda  2024
# 45  07051012020248010070    Segunda  2024
# 46  07047244920248010070      Terça  2024
# 47  07115925620248010001      Terça  2024
# 48  07169243820238010001    Segunda  2024
# 49  07080815020248010001     Quarta  2024
# 50  07077835820248010001     Quinta  2024
# 51  07063960820248010001      Terça  2024
# 52  07003136720248010003     Quinta  2024

# %% [markdown]
# ### 7.2 Verificando ano mínimo e máximo do conjunto de dados

# %%
min = df['ano'].min()
max = df['ano'].max()

print(f"Ano mínimo: {min}")
print(f"Ano máximo: {max}")
# Out:
# Ano mínimo: 2024
# Ano máximo: 2026

# %% [markdown]
# ## 💾 8. EXPORTAÇÃO DE DADOS INTERMEDIÁRIOS

# %% [markdown]
# ### 8.1 Exportação para CSV
# **Descrição**: Exportação dos dados processados para uso posterior:
#
# *  processos_decisao_dia_ano.csv: Dataset completo com decisões e features temporais
# *  numeros_processos.csv: Lista única de números de processo para scraping de PDFs

# %%
df.to_csv("processos_dia_ano.csv", sep=';', index=False)
df['numero_processo'].drop_duplicates().to_csv("numeros_processos.csv", index=False)

print("\n=== ARQUIVOS EXPORTADOS ===")
print("  - processos_dia_ano.csv")
print("  - numeros_processos.csv")
# Out:
# === ARQUIVOS EXPORTADOS ===
#   - processos_dia_ano.csv
#   - numeros_processos.csv

# %% [markdown]
# ## 📄 9. INSTRUÇÕES PARA COLETA DE DOCUMENTOS COMPLETOS

# %% [markdown]
# ### 9.1 Scraping de PDFs (Executar Localmente)
# **Pré-requisitos:**
# 1. Clone o repositório: `git clone https://github.com/GiovanniBrigido/trabalho-final-deep-learning.git`
# 2. Navegue até o diretório do projeto
# 3. Execute os seguintes comandos:
#
# **Comandos:**
# ```bash
# python -m venv venv
# pip install -r requirements.txt
# playwright install chromium
# python ./scraper_pdf_tjce.py
# ```
#
# O que o script faz:
#
# *   Lê o arquivo numeros_processos.csv
# *   Acessa o site do TJCE
# *   Baixa os PDFs das sentenças completas
# *   Salva os arquivos na pasta data/decisoes

# %% [markdown]
# ### 9.2 Extração de Texto dos PDFs (Executar Localmente)
# Após gerar os arquivos básicos acima, execute o script `scraper_pdf_tjce.py` para realizar a extração de PDF's.
#
# **Execute:**
# ```bash
# python ./extrair_decisoes.py
# ```
# **O que o script faz**:
#
# * Lê todos os PDFs baixados
# * Extrai o texto completo de cada sentença com a bib PyPDF2
# * Gera o arquivo decisoes_extraidas.csv com:
#    * Número do processo
#    * Texto completo da decisão
#    * Metadados adicionais
#
# **Arquivo gerado:**
#
# *  decisoes_extraidas.csv
# * **!! SERÁ USADO NO NOTEBOOK 2 !!**
